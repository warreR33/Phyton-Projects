# %%
name = input("Enter your name")
weight = float(input("Enter your weight in KG:"))
height = float(input("Enter your weight in M:"))
BMI = (weight) / (height * height)

if BMI > 0:
    if (BMI > 16 and BMI <= 18.5):
        print(name + " you are Moderate Thinness")
    elif (BMI >= 18.5 and BMI <= 25):
        print(name +  " you are Normal")
    elif (BMI > 25 and BMI <= 30):
        print(name +  " you are Overweight")
    elif (BMI > 30 and BMI <= 35):
        print(name +  " you are Obese Class I")
    elif (BMI > 35 and BMI <= 40):
        print(name + " you are Obese Class II")
    elif (BMI > 40):
        print(name +  " you are Obese Class III")
    else:
        print(name + " you are Enter valid Inputs") 

print(BMI)
# Out:
# Enter your name Yuyu
# Enter your weight in KG: 95
# Enter your weight in M: 1.80
# Yuyu you are Overweight
# 29.320987654320987
